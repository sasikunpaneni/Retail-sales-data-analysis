# %% [markdown]
# # 01 - Exploratory Data Analysis (EDA)
# Load sales data, view trends, seasonality, and KPIs.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/sales_data.csv', parse_dates=['Date'])
df.head()
